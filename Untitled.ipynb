# %%
import pandas as pd

# %%
import os

# %%
excel01 = pd.read_excel("C:/Users/SWCarpentry/Desktop/hackyhour-versorgungslandkarte-master/versorgung_in_Bearb_20180413.xlsx")

# %%
print(excel01)
# Out:
#                                                    title  \
# 0                   10/90 Report on Health Research, The
# 1      &#1057;&#1087;&#1077;&#1083;&#1077;&#1086;&#10...
# 2      16 de Abril: Revista Cubana de los Estudiantes...
# 3                                 20/20 (via EBSCO Host)
# 4                                              2000 agro
# 5                                              3 Biotech
# 6                                3D Printing in Medicine
# 7      3R : Fachzeitschrift für sichere und effizient...
# 8                 4S Review (ältere Jahrgänge via JSTOR)
# 9                          A.A.V. Newsletter (via JSTOR)
# 10                            A.I.H.P. Notes (via JSTOR)
# 11     A Magyar Földtani és Geofizikai Intézet évi je...
# 12     A Peste : Revista de Psicanálise e Sociedade e...
# 13                   AAAS Report: Research & Development
# 14                           AACN Advanced Critical Care
# ...

# %%
excel01.shape
# Out:
# (35134, 31)

# %%
excel02 = pd.read_excel("C:/Users/SWCarpentry/Desktop/hackyhour-versorgungslandkarte-master/2018-12-20-versorgung_print.xlsx")

# %%
excel02.shape
# Out:
# (35753, 26)

# %%
excel01.columns
# Out:
# Index(['title', 'publisher', 'Print Preis brutto 2017',
#        'Print Preis brutto 2018', 'DOD 2017', 'Lieferant', 'ZDB vh',
#        'Verlängert f. 2019', 'Gekündigt', 'subjects', 'from', 'to',
#        'electronic issn', 'print issn', 'used zdbid', 'lic/free',
#        'count libs in ger', 'in ZBMED?', 'libs in ger',
#        'count libs not in ger', 'libs not in ger', 'il count e', 'libs il e',
#        'il count k', 'libs il k', 'Unnamed: 25', 'subito e', 'libs subito e',
#        'subito p', 'libs subito p', 'subito link'],
#       dtype='object')

# %%
excel02.columns
# Out:
# Index(['title', 'publisher', 'subjects', 'from', 'to', 'electronic issn',
#        'print issn', 'electronic zdbid', 'print zdbid', 'lic/free',
#        'count libs in ger', 'in ZBMED?', 'libs in ger',
#        'count libs not in ger', 'libs not in ger', 'libs print', 'il count e',
#        'libs il e', 'il count k', 'libs il k', 'il link', 'subito e',
#        'libs subito e', 'subito p', 'libs subito p', 'subito link'],
#       dtype='object')

# %%
excel01.head(10)
# Out:
#                                                title  \
# 0               10/90 Report on Health Research, The
# 1  &#1057;&#1087;&#1077;&#1083;&#1077;&#1086;&#10...
# 2  16 de Abril: Revista Cubana de los Estudiantes...
# 3                             20/20 (via EBSCO Host)
# 4                                          2000 agro
# 5                                          3 Biotech
# 6                            3D Printing in Medicine
# 7  3R : Fachzeitschrift für sichere und effizient...
# 8             4S Review (ältere Jahrgänge via JSTOR)
# 9                      A.A.V. Newsletter (via JSTOR)
#
#                                            publisher Print Preis brutto 2017  \
# 0  World Health Organization/Global Forum for Hea...                     NaN
# 1   Ukrainian Institute of Speleology and Karstology                     NaN
# 2  Instituto Superior de Ciencias Médicas de La H...                     NaN
# ...

# %%
excel02.head(10)
# Out:
#                                                title  \
# 0               10/90 Report on Health Research, The
# 1  &#1057;&#1087;&#1077;&#1083;&#1077;&#1086;&#10...
# 2  16 de Abril: Revista Cubana de los Estudiantes...
# 3                             20/20 (via EBSCO Host)
# 4                                          2000 agro
# 5  25 Questions & Answers on Health & Human Right...
# 6                                         3 Biotech
# 7                    3 Biotech (älter als 12 Monate)
# 8                            3D Printing in Medicine
# 9  3R : Fachzeitschrift für sichere und effizient...
#
#                                            publisher  \
# 0  World Health Organization/Global Forum for Hea...
# 1   Ukrainian Institute of Speleology and Karstology
# 2  Instituto Superior de Ciencias Médicas de La H...
# 3                                     via EBSCO Host
# 4                         [Verlag nicht ermittelbar]
# 5                                     via EBSCO Host
# ...

# %%
excel_merge = pd.merge(excel01,excel02)

# %%
excel_merge.shape
# Out:
# (15280, 35)

# %%
excel_concat = pd.concat([excel01, excel02], axis = 1)

# %%
excel_concat.shape
# Out:
# (35753, 57)

# %%
excel_concat.head(10)
# Out:
#                                                title  \
# 0               10/90 Report on Health Research, The
# 1  &#1057;&#1087;&#1077;&#1083;&#1077;&#1086;&#10...
# 2  16 de Abril: Revista Cubana de los Estudiantes...
# 3                             20/20 (via EBSCO Host)
# 4                                          2000 agro
# 5                                          3 Biotech
# 6                            3D Printing in Medicine
# 7  3R : Fachzeitschrift für sichere und effizient...
# 8             4S Review (ältere Jahrgänge via JSTOR)
# 9                      A.A.V. Newsletter (via JSTOR)
#
#                                            publisher Print Preis brutto 2017  \
# 0  World Health Organization/Global Forum for Hea...                     NaN
# 1   Ukrainian Institute of Speleology and Karstology                     NaN
# 2  Instituto Superior de Ciencias Médicas de La H...                     NaN
# ...
